# %% [markdown]
# #Actividad 1: Comparación de Rendimiento de Clientes con Boxplots
#
# Consigna:
#
# Utilizarás un dataset que contiene información sobre las compras realizadas por diferentes clientes. Las columnas son: cliente, importe_compra, y mes.
#
# Cargá el dataset y visualizá los primeros registros.
#
# Creá un boxplot que muestre la distribución de las compras por mes. Asegurate de personalizar el gráfico con títulos y etiquetas adecuadas.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.DataFrame({
'cliente': ['Cliente 1', 'Cliente 2', 'Cliente 3', 'Cliente 4', 'Cliente 5'],
'importe_compra': [200, 450, 120, 700, 30],
'mes': ['Enero', 'Enero', 'Febrero', 'Febrero', 'Febrero']
})

data
# Out:
#      cliente  importe_compra      mes
# 0  Cliente 1             200    Enero
# 1  Cliente 2             450    Enero
# 2  Cliente 3             120  Febrero
# 3  Cliente 4             700  Febrero
# 4  Cliente 5              30  Febrero

# %%
sns.boxplot(x='mes', y='importe_compra', data=data, palette='husl')
plt.title('Distribución de Compras por Mes')
plt.xlabel('Mes')
plt.ylabel('Importe de Compra')
plt.show()
# Out:
# /tmp/ipython-input-1080541102.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='mes', y='importe_compra', data=data, palette='husl')

# %% [markdown]
# #Actividad 2: Análisis de Productos con Violin Plots y Gráficos de Barras
# Consigna:
#
# Utilizarás un dataset que contiene información sobre los precios de diferentes productos categorizados. Las columnas son: categoría, producto, y precio.
#
# Cargá el dataset y visualiza los primeros registros.
#
# Creá un subplot que contenga un violin plot mostrando la distribución de precios por categoría, junto con un gráfico de barras que represente el precio promedio por categoría.

# %%
data_1 = pd.DataFrame({
    'categoría': ['Electrónica', 'Electrónica', 'Ropa', 'Ropa', 'Alimentos', 'Alimentos'],
    'producto': ['Televisor', 'Radio', 'Camisa', 'Pantalón', 'Pan', 'Leche'],
    'precio': [300, 150, 20, 40, 2, 1.5]
})

data_1
# Out:
#      categoría   producto  precio
# 0  Electrónica  Televisor   300.0
# 1  Electrónica      Radio   150.0
# 2         Ropa     Camisa    20.0
# 3         Ropa   Pantalón    40.0
# 4    Alimentos        Pan     2.0
# 5    Alimentos      Leche     1.5

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 6))

sns.violinplot(x='categoría', y='precio', data=data_1, ax=axs[0, 0], color='lightgray')
axs[0, 0].set_title('Distribución de Precios por Categoría')
axs[0, 0].set_xlabel('Categoría')
axs[0, 0].set_ylabel('Precio')

sns.barplot(x='categoría', y='precio', data=data_1, palette='viridis', ci=None, ax=axs[0, 1])
axs[0, 1].set_title('Precio Promedio por Categoría')
axs[0, 1].set_xlabel('Categoría')
axs[0, 1].set_ylabel('Precio Promedio')

sns.stripplot(x='categoría', y='precio', data=data_1, ax=axs[1, 0])
axs[1, 0].set_title('Precio por Producto')
axs[1, 0].set_xlabel('Categoría')
axs[1, 0].set_ylabel('Precio')

axs[1, 1].axis('off')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1787967103.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='categoría', y='precio', data=data_1, palette='viridis', ci=None, ax=axs[0, 1])
# /tmp/ipython-input-1787967103.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='categoría', y='precio', data=data_1, palette='viridis', ci=None, ax=axs[0, 1])
