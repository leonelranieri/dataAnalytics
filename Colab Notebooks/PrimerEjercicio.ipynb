# %% [markdown]
# # Leonel Alejandro Ranieri - Data Trainne
# Aprendiendo se llega lejos.
#
# ---
#
# ## Sobre el notebook
# **Objetivo:** Familiarizarme con los cuardenillos de Google Colab.
# **Aplicación:** Dejar constancia clara, limpia y útil dentro del notebbok para su análisis.
# **Formato:**:
# - Títulos: (`#`, `##`)
# -  Formato enriquecido: (**negrita**, *cursiva*)
# - Listas de puntos
# - Links de referencia
# - Imagen embebida desde el drive
# - Cita de cierre
#
# ---
#
# ## 📚 Fuente
# [Documentación Google Colab](https://colab.google/)
# > Si necesitas conocer algo, lo buscas ahí
#
# ---
#
# <center>
#
# ## 🖼️ Visualizanco mi mood
# [Soy yo](https://drive.google.com/drive/u/0/recent)
#
# </center>
#
# ---
#
# ## 🎙️ Frase Final
# > **Los datos son información y la información es conocimiento.**
#
# ---
#
# <center>
#
# *Fin de la presentación. LR.*
#
# <center>
#
# ---

# %%
# Actividad 2
import math

num = float((input("ingrese un número para verificar si es par o impar:")))
mi_num = math.floor(num)
if mi_num % 2 == 0:
  print("El número es par")
else:
  print("El número es impar")
# Out:
# ingrese un número para verificar si es par o impar:8
# El número es par
