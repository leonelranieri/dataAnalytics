# %%
import pandas as pd

ventas = pd.DataFrame({
    "Entradas":[41,32,56,18],
    "Salidas":[17,54,6,78],
    "Valoración":[15,12,18,16],
    "Límite":["No", "Si", "Si","No"],
    "Cambio":[1.47, 1.23, 1.48, 1.68],
    },
    index=["Ene","Feb","Mar","Abr"],
)

ventas
# Out:
#      Entradas  Salidas  Valoración Límite  Cambio
# Ene        41       17          15     No    1.47
# Feb        32       54          12     Si    1.23
# Mar        56        6          18     Si    1.48
# Abr        18       78          16     No    1.68
